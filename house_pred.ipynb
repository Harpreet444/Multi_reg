# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv("C:\\Users\\hsd28\\Downloads\\Housing.csv")
df = data.drop(['mainroad','guestroom',	'basement',	'hotwaterheating',	'airconditioning',	'parking',	'prefarea',	'furnishingstatus'],axis=1)
df
# Out:
#         price  area  bedrooms  bathrooms  stories
# 0    13300000  7420         4          2        3
# 1    12250000  8960         4          4        4
# 2    12250000  9960         3          2        2
# 3    12215000  7500         4          2        2
# 4    11410000  7420         4          1        2
# ..        ...   ...       ...        ...      ...
# 540   1820000  3000         2          1        1
# 541   1767150  2400         3          1        1
# 542   1750000  3620         2          1        1
# 543   1750000  2910         3          1        1
# 544   1750000  3850         3          1        2
#
# [545 rows x 5 columns]

# %%
# import matplotlib.pyplot as plt

# Ensure df is defined and contains the required columns
features = ['area', 'bedrooms', 'bathrooms', 'stories']
target = 'price'

for feature in features:
    plt.figure()
    plt.scatter(df[feature], df[target], color='g', marker='+')
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.title(f'Scatter Plot of {feature} vs {target}')
    plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','bathrooms','stories']],df[['price']])
# Out:
# LinearRegression()

# %%
reg.predict(df[['area','bedrooms','bathrooms','stories']])
# Out:
# array([[ 7326017.9251189 ],
#        [10843211.50192761],
#        [ 7561389.47225783],
#        [ 6824824.87028828],
#        [ 5594242.44267015],
#        [ 7295114.84034423],
#        [ 9498621.74552692],
#        [11529513.37230637],
#        [ 5852659.0545773 ],
#        [ 7024676.64335441],
#        [ 7592488.14983345],
#        [ 7454968.69965155],
#        [ 6463801.66247681],
#        [ 5304727.15318737],
#        [ 6740536.70502334],
#        [ 5054607.75309933],
#        [ 6482802.88394057],
#        [ 8069743.82386129],
#        [ 5524458.53134261],
#        [ 6216102.99262352],
#        [ 4217871.21786944],
#        [ 5963825.93896817],
#        [ 5103767.32989339],
#        [ 5509257.5541716 ],
#        [ 7120561.13429856],
#        [ 6460001.41818406],
#        [ 7119682.75067322],
#        [ 5417287.48404545],
#        [ 7194131.35750964],
#        [ 6064776.01173782],
#        [ 7680218.78385418],
#        [ 6299526.70667234],
#        [ 5829160.86558718],
# ...
